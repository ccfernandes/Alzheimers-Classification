# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_3.csv")
df.head()
# Out:
#    RID    EXAMDATE DX_bl  MEM_AVG  LANG_AVG  VISSPAT_AVG  PLAN_AVG  ORGAN_AVG  \
# 0    2  2010-09-22    CN  0.93750  0.750000     0.428571    0.6875   0.750000
# 1    8  2010-09-27    CN  0.62500  0.555556     0.500000    0.5000   0.416667
# 2   15  2011-11-03    CN  0.75000  0.694444     0.392857    0.5000   0.583333
# 3   21  2010-10-07    CN  0.31250  0.277778     0.250000    0.2500   0.350000
# 4   23  2010-12-21    CN  0.46875  0.333333     0.357143    0.2500   0.250000
#
#    DIVATT_AVG ABETA_bl  ...  FAQTOTAL  MH2NEURL  MH4CARD  MH5RESP  PTGENDER  \
# 0      0.6875      NaN  ...       0.0       1.0      0.0      0.0         0
# 1      0.3750     1700  ...       0.0       1.0      0.0      0.0         1
# 2      0.8750      NaN  ...       0.0       0.0      1.0      1.0         0
# 3      0.2500      NaN  ...       0.0       1.0      1.0      0.0         1
# 4      0.3750     1647  ...       0.0       0.0      1.0      0.0         0
#
# ...

# %%
#histogram plot for ventricles
import matplotlib.pyplot as plt
# %matplotlib inline
x1 = df.loc[df.DX_bl=='CN','Ventricles_bl']
x2 = df.loc[df.DX_bl=='MCI','Ventricles_bl']
x3 = df.loc[df.DX_bl=='AD','Ventricles_bl']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})
plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline Ventricles volume', ylabel='Frequency')
plt.xlim(-2,5)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x1 = df.loc[df.DX_bl=='CN','Entorhinal_bl']
x2 = df.loc[df.DX_bl=='MCI','Entorhinal_bl']
x3 = df.loc[df.DX_bl=='AD','Entorhinal_bl']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})
plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline Entorhinal volume', ylabel='Frequency')
plt.xlim(-3,4)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x1 = df.loc[df.DX_bl=='CN','CEREBRUM_TCB']
x2 = df.loc[df.DX_bl=='MCI','CEREBRUM_TCB']
x3 = df.loc[df.DX_bl=='AD','CEREBRUM_TCB']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})

plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline Cerebral volume', ylabel='Frequency')
plt.xlim(-2.5,4)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x1 = df.loc[df.DX_bl=='CN','TOTAL_CSF']
x2 = df.loc[df.DX_bl=='MCI','TOTAL_CSF']
x3 = df.loc[df.DX_bl=='AD','TOTAL_CSF']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})

plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline CSF volume', ylabel='Frequency')
plt.xlim(-2.5,4)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x1 = df.loc[df.DX_bl=='CN','TOTAL_HIPPO']
x2 = df.loc[df.DX_bl=='MCI','TOTAL_HIPPO']
x3 = df.loc[df.DX_bl=='AD','TOTAL_HIPPO']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})

plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline hippocampus volume', ylabel='Frequency')
plt.xlim(-4,4)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x1 = df.loc[df.DX_bl=='CN','RAVLT_immediate_bl']
x2 = df.loc[df.DX_bl=='MCI','RAVLT_immediate_bl']
x3 = df.loc[df.DX_bl=='AD','RAVLT_immediate_bl']

kwargs = dict(hist_kws={'alpha':.6},kde_kws={'linewidth':2})

plt.figure(figsize=(15,7),dpi=80)
sns.distplot(x1, color="dodgerblue", label='CN', **kwargs)
sns.distplot(x2, color="green", label='MCI', **kwargs)
sns.distplot(x3, color="deeppink", label='AD', **kwargs)
plt.gca().set(title='Frequency Histogram of baseline RAVLT scores', ylabel='Frequency')
plt.xlim(-3,3)
plt.legend();
# Out:
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\AZD\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
