# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import io

from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from IPython.display import Image
from IPython.display import display

# %%
# Import datta
# ==================================

# Read data
data = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_4.csv", low_memory=False);

#plot boxplots

#imaging
cols = ["TOTAL_HIPPO","Ventricles_bl","Entorhinal_bl", "TOTAL_CSF", "CEREBRUM_TCB"]

#cog tests 
#cols2 = ["","",""]

cols2 = ["MMSE_bl","ADAS11_bl","ADAS13_bl","RAVLT_immediate_bl"]


#df = data_base.copy()
df=data

fig, axes = plt.subplots(1, 5, figsize=(24, 6))
ax = axes.ravel()

for c in cols:
    i = cols.index(c)
    sns.boxplot(x="DX_bl", y=c, data=df, color="maroon", ax=ax[i], order=["CN", "MCI", "AD"], saturation=0.7, fliersize=5)
    ax[i].set_ylabel(c)
    ax[i].set_xlabel("")
    ax[i].set_yticklabels("")

# %%
# Import datta
# ==================================

# Read data
data = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_4.csv", low_memory=False);

#plot boxplots

#imaging
cols = ["MMSE_bl","ADAS11_bl","ADAS13_bl","RAVLT_immediate_bl"]

#cog tests 
#cols2 = ["","",""]

cols2 = ["MMSE_bl","ADAS11_bl","ADAS13_bl","RAVLT_immediate_bl"]


#df = data_base.copy()
df=data

fig, axes = plt.subplots(1, 4, figsize=(24, 6))
ax = axes.ravel()

for c in cols:
    i = cols.index(c)
    sns.boxplot(x="DX_bl", y=c, data=df, color="maroon", ax=ax[i], order=["CN", "MCI", "AD"], saturation=0.7, fliersize=5)
    ax[i].set_ylabel(c)
    ax[i].set_xlabel("")
    ax[i].set_yticklabels("")

# %%
# Import datta
# ==================================

# Read data
data = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_4.csv", low_memory=False);

#plot boxplots

#imaging
cols = ["MEM_AVG","LANG_AVG","VISSPAT_AVG","PLAN_AVG","ORGAN_AVG","DIVATT_AVG"]

#df = data_base.copy()
df=data

fig, axes = plt.subplots(1, 6, figsize=(24, 6))
ax = axes.ravel()

for c in cols:
    i = cols.index(c)
    sns.boxplot(x="DX_bl", y=c, data=df, color="maroon", ax=ax[i], order=["CN", "MCI", "AD"], saturation=0.7, fliersize=5)
    ax[i].set_ylabel(c)
    ax[i].set_xlabel("")
    ax[i].set_yticklabels("")

# %%
# Import datta
# ==================================

# Read data
data = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_4.csv", low_memory=False);

#plot boxplots

#imaging
cols = ["MH2NEURL","MH4CARD","MH5RESP","PTGENDER","PTMARRY","PTEDUCAT","PTRACCAT"]

#df = data_base.copy()
df=data

fig, axes = plt.subplots(1, 7, figsize=(24, 6))
ax = axes.ravel()

for c in cols:
    i = cols.index(c)
    sns.boxplot(x="DX_bl", y=c, data=df, color="maroon", ax=ax[i], order=["CN", "MCI", "AD"], saturation=0.7, fliersize=5)
    ax[i].set_ylabel(c)
    ax[i].set_xlabel("")
    ax[i].set_yticklabels("")

# %%
# Read data
data = pd.read_csv("C:\\Users\\AZD\\Desktop\\merged_normalized_4.csv", low_memory=False);

#plot boxplots

#imaging
cols = ["AGE","APOE4","FAQTOTAL","ABETA_bl"]

#df = data_base.copy()
df=data

fig, axes = plt.subplots(1, 4, figsize=(24, 6))
ax = axes.ravel()

for c in cols:
    i = cols.index(c)
    sns.boxplot(x="DX_bl", y=c, data=df, color="maroon", ax=ax[i], order=["CN", "MCI", "AD"], saturation=0.7, fliersize=5)
    ax[i].set_ylabel(c)
    ax[i].set_xlabel("")
    ax[i].set_yticklabels("")
